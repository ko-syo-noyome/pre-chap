# %% [markdown]
# <a href="https://colab.research.google.com/github/ko-syo-noyome/pre-chap/blob/main/%E5%AE%8C%E6%88%90%E3%83%A2%E3%83%87%E3%83%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import os, glob #特定のパターンにマッチするファイルを取得することができる。：かたまり
import numpy as np
from sklearn import model_selection

classes=["model1-base","model1-controlroom","model1-cover","model1-joint1","model1-joint2","model1-patrollight","model1-rot","model1-shorel","model1-shuft","model1-wheel"]
#classes=["model2-base","model2-controlroom","model2-cover","model2-joint1","model2-joint2","model2-patrollight","model2-rot","model2-shorel","model2-shuft","model2-wheel"]
num_classes=len(classes)

for index, classlabel in enumerate(classes):
  photos_dir="drive/MyDrive/learning model/excavator/people/"+classlabel
  print(photos_dir)
# Out:
# drive/MyDrive/learning-model/excavator/people/model1-base
# drive/MyDrive/learning-model/excavator/people/model1-controlroom
# drive/MyDrive/learning-model/excavator/people/model1-cover
# drive/MyDrive/learning-model/excavator/people/model1-joint1
# drive/MyDrive/learning-model/excavator/people/model1-joint2
# drive/MyDrive/learning-model/excavator/people/model1-patrollight
# drive/MyDrive/learning-model/excavator/people/model1-rot
# drive/MyDrive/learning-model/excavator/people/model1-shorel
# drive/MyDrive/learning-model/excavator/people/model1-shuft
# drive/MyDrive/learning-model/excavator/people/model1-wheel

# %%
#classes=["image1","image2"]
classes=["model1-base","model1-controlroom","model1-cover","model1-joint1","model1-joint2","model1-patrollight","model1-rot","model1-shorel","model1-shuft","model1-wheel"]
num_classes=len(classes)
image_size=100 #計算時間短縮で100に変換

# #画像の読み込み
X=[]
Y=[]

for index, classlabel in enumerate(classes):
  photos_dir="drive/MyDrive/learning model/excavator/people/"+classlabel

  files=glob.glob(photos_dir+"/*.jpg")
  #print(files)
  
  for i,file in enumerate(files):
    #print(i)
    if i >=200: break
    image=Image.open(file)
    image=image.convert("RGB")
    image=image.resize((image_size,image_size))
    data=np.asarray(image)
    X.append(data)
    Y.append(index)

#tensorflowが読み込みやすいnumpyの配列にする
X=np.array(X)
Y=np.array(Y)
# Out:
# ['drive/MyDrive/learning model/excavator/people/model1-base/model1-01.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-02.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-03.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-04.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-05.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-06.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-07.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-08.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-09.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-10.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-12.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-11.jpg', 'drive/MyDrive/learning model/excavator/people/model1-base/model1-13.jpg', 'drive/MyDrive/learnin
# ...

# %%
X_train,X_test,y_train,y_test=model_selection.train_test_split(X,Y)
xy=(X_train,X_test,y_train,y_test)
np.save("./drive/MyDrive/learning model/excavator/model.npy",xy)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import numpy as np
import tensorflow
import keras
import datetime




classes=["model1-base","model1-controlroom","model1-cover","model1-joint1","model1-joint2","model1-patrollight","model1-rot","model1-shorel","model1-shuft","model1-wheel"]
num_classes=len(classes)
image_size=100


# main 関数

def model_train(X,y):
    model=Sequential()
    model.add(Conv2D(32,(3,3),padding='same',input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64,(3,3),padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))


    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10))
    model.add(Activation('softmax'))
    
    opt = tensorflow.keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

    model.compile(loss='categorical_crossentropy',
                        optimizer=opt,metrics=['accuracy'])


    model.fit(X,y,batch_size=32,epochs=100)

    model.save('./drive/MyDrive/learning model/excavator/cnn-model.h5')

    return model


def main():
    X_train,X_test,y_train,y_test=np.load("./drive/MyDrive/learning model/excavator/model.npy",allow_pickle=True)

    print(X_train.shape)
   
    X_train=X_train.astype("float")/256
    X_test=X_test.astype("float")/256

    y_train=np_utils.to_categorical(y_train, num_classes)
    y_test=np_utils.to_categorical(y_test,num_classes)

    model=model_train(X_train,y_train)
    model_eval(model,X_test,y_test)


    return 

def model_eval(model,X,y):
    scores=model.evaluate(X,y,verbose=1)
    print('Test Loss:',scores[0])
    print('Test Accuracy:',scores[1])


if __name__=="__main__":
    main()
# Out:
# (225, 100, 100, 3)
# Epoch 1/100
# 8/8 [==============================] - 13s 1s/step - loss: 2.4758 - accuracy: 0.1111
# Epoch 2/100
# 8/8 [==============================] - 12s 1s/step - loss: 2.2153 - accuracy: 0.1867
# Epoch 3/100
# 8/8 [==============================] - 12s 1s/step - loss: 2.1642 - accuracy: 0.2533
# Epoch 4/100
# 8/8 [==============================] - 12s 1s/step - loss: 1.9869 - accuracy: 0.2844
# Epoch 5/100
# 8/8 [==============================] - 12s 1s/step - loss: 1.8641 - accuracy: 0.3867
# Epoch 6/100
# 8/8 [==============================] - 12s 1s/step - loss: 1.6560 - accuracy: 0.4311
# Epoch 7/100
# 8/8 [==============================] - 12s 1s/step - loss: 1.5340 - accuracy: 0.5156
# Epoch 8/100
# 8/8 [==============================] - 12s 1s/step - loss: 1.3785 - accuracy: 0.5600
# Epoch 9/100
# 8/8 [==============================] - 12s 1s/step - loss: 1.2880 - accuracy: 0.5822
# Epoch 10/100
# ...
